# %%
import os
import psycopg2
import psycopg2.extras
from sentence_transformers import SentenceTransformer
import pandas as pd
# Initialize the connection to PostgreSQL
connection = psycopg2.connect(
    dbname="your_db_name",
    user="your_username",
    password="your_password",
    host="localhost",
    port="5432"
)

# Initialize the embedding model using Hugging Face
model_name = "sentence-transformers/all-MiniLM-L6-v2"  # You can change the model as needed
embedding_model = SentenceTransformer(model_name)



read = pd.read_csv(r"C:\Users\atul.gupta\cleaned_new_pepsico.csv")

read

new_alis = read[['DB Field Name','Definition']].iloc[:3000]
new_alis['embedding'] = None
print(new_alis)



for index, row in new_alis.iterrows():
    field_dict = {}
    field_name = row['DB Field Name']
    definition = row['Definition']
    field_dict[field_name] = definition
    #print(field_dict)
    embeddings = embedding_model.encode([field_dict]).tolist()
    new_alis.at[index, 'embedding'] = embeddings[0]
    #print(embeddings)
new_alis


with connection.cursor() as cursor:
    for index,row in new_alis.iterrows():
        embedding_vector = row['embedding']
        #print(embedding_vector) 
        
        cursor.execute(
            """
            INSERT INTO test_3k(db_field_name,definition,embedding)
            VALUES(%s,%s,%s)
            """,
            (row['DB Field Name'], row['Definition'], embedding_vector)
        )  
print("Done")
connection.commit()
# Out:
# c:\Users\atul.gupta\Anaconda3\lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
#                                DB Field Name  \
# 0        HID_Form_Status__Regen_Ag__Projects
# 1     HID_Form_Status__Regen_Ag__Agriculture
# 2     HID_Form_Status__Regen_Ag__Commodities
# 3                 HID_Forms_Completion_Check
# 4                                  Thank_you
# ...                                      ...
# 2995         MaterialMarketingTargetTypeCode
# 2996                                   APLAL
# 2997                                   PLNNR
# 2998                                   STLAN
# 2999                                   STLAL
#
#                                              Definition embedding
# 0     Calculated value of overall form completion fo...      None
# 1     Calculated value of overall form completion fo...      None
# 2     Calculated value of overall form completion fo...      None
# 3     Calculated value of overall form completion fo...      None
# 4     Message is typically displayed on the last pag...      None
# ...                                                 ...       ...
# 2995  Represents what kind of marketing is being don...      None
# 2996  The group counter is used in conjunction with ...      None
# 2997  The task lists are used in production and main...      None
# 2998  Bill of Materials BOM can have different usage...      None
# 2999  In manufacturing alternative BOMs are used to ...      None
#
# [3000 rows x 3 columns]
# Done

# %%
import numpy as np
import ast

def cosine_similarity(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

def search_similar_definitions(query, top_n=5):
    query_embedding = embedding_model.encode([query]).tolist()[0]

    with connection.cursor() as cursor:
        cursor.execute("SELECT db_field_name, definition, embedding FROM test_3k")
        results = cursor.fetchall()
        

    similarities = []
    for row in results:
        db_field_name, definition, embedding_str = row
        
        
        embedding = ast.literal_eval(embedding_str)  
        
        similarity = cosine_similarity(query_embedding, embedding)
        similarities.append((db_field_name, definition, similarity))

    
    similarities.sort(key=lambda x: x[2], reverse=True)
    return similarities[:top_n]
#query = "Footer"
query = ["Footer","asset_status","UpdatedById","MarketUnitName","JobFunctionName","PreferredName","GoLiveDate","CurrencyCode","PayrollEndDate","RequisitionId","DateOfDeath","ProbationPeriodEndDate","ResignationDate","ConfirmationDate","HireTypeCode","TerminationNotificationDate","CorporateCardNumber","ResignationTaiwanDate","LocationTypeCode","GeoZoneCode","PrimaryOwnerId","BusinessUnitName"]
for attribute in query:
    results = search_similar_definitions(attribute, top_n=5)
    print("Attribute_name:",attribute)
    for result in results:
        print(f"Field Name: {result[0]}, Definition: {result[1]}, Similarity: {result[2]}")
    print("\n")
    print("\n")
# Out:
# Attribute_name: Footer
# Field Name: LOAD_PT, Definition: A subdivision or part of the shipping point, Similarity: 0.26756432382522505
# Field Name: XTNSupplierOfficeResponsibleSalesPersonName, Definition: Name of the Salesperson at vendor's office, Similarity: 0.22524306370421826
# Field Name: CustomDescription, Definition: Additional line of space for more details regarding the address if needed, Similarity: 0.2229357704865876
# Field Name: AddressLine1Text, Definition: Additional line of space for more details regarding the address if needed, Similarity: 0.2229357704865876
# Field Name: AddressLine3LabelText, Definition: Additional line of space for more details regarding the address if needed, Similarity: 0.2229357704865876
#
#
#
#
# Attribute_name: asset_status
# Field Name: STS_ITM, Definition: Current status for the Item, Similarity: 0.44941866936044644
# Field Name: BIC_ZTRSTAT, Definition: Indicates the status of request, Similarity: 0.42794511303242405
# Field Name: CH_ON, Definition: This field used for storing Last Changed date for Asset, Similarity: 0.4146369284218203
# Field Name: XTNSnapshotStatusCode, Definition: The code specifies the status of the snapshot, Similarity: 0.4030539284068297
# Field Name: BIC_ZDEL_OVEH, Definition: This field consists of the indicator for status header, Similarity: 0.3949498339435439
#
#
#
#
# Attribute_name: UpdatedById
# Field Name: XTNUpdatedById, Definition: Last User Identifier who updated the record, Similarity: 0.5720941709245788
# Field Name: XTNUpdatedById, Definition: Last User Identifier who updated the data record, Similarity: 0.5606651501410224
# Field Name: XTNUpdatedById, Definition: Last User IdJob Id Updated this Record, Similarity: 0.5357973543350785
# Field Name: VBAP__XTNUpdatedById, Definition: Last User IDJob ID Updated this Record, Similarity: 0.5357973543350785
# Field Name: XTNCreatedById, Definition: Last User IdJob Id which updated this Record, Similarity: 0.5272218376038412
#
#
#
#
# Attribute_name: MarketUnitName
# Field Name: MarketUnitName, Definition: This field provides the market unit name, Similarity: 0.704044226605289
# Field Name: MarketUnitName, Definition: This field provides the name of the Market Unit, Similarity: 0.6815141296118954
# Field Name: VendorDescription, Definition: This field provides the name of the vendor, Similarity: 0.5032180482883742
# Field Name: ProductPrimarySellingUnitofMeasureName, Definition: Name of product primary selling unit of measure, Similarity: 0.45912149804912206
# Field Name: TradingPartnerCode, Definition: This field contains the company code which is and unique code for each business market, Similarity: 0.44862794177237125
#
#
#
#
# Attribute_name: JobFunctionName
# Field Name: JOB_TITLE, Definition: Unique name for a job in the system  A job defines the general tasks and responsibilities of a role within the Company based on the Job Function and SubFunction and Grade Band Level of the role as defined by the Global Job Catalog The naming convention for the Job Title is defined within the Global Job Catalog with the exception of Frontline jobs , Similarity: 0.6053980751742221
# Field Name: JobTitleName, Definition: Unique name for a job in the system  A job defines the general tasks and responsibilities of a role within the Company based on the Job Function and SubFunction and Grade Band Level of the role as defined by the Global Job Catalog The naming convention for the Job Title is defined within the Global Job Catalog with the exception of Frontline jobs , Similarity: 0.6053980751742221
# Field Name: DepartmentName, Definition: Name of the particular functional area within the Company to which the employee is assigned, Similarity: 0.5065853974271436
# Field Name: JOB_SUB_FUNCTION, Definition: The identifying code of the secondary function to which the employee is assigned based on their Job and the Job Function of that job eg Finance Strategy Brand Marketing Sales Business Development etc This field will be inherited based on the Job Code selection and is defined by the valid SubFunction values for each Function in the Global Job Catalog, Similarity: 0.4862482551846117
# Field Name: JobSubFunctionCode, Definition: The identifying code of the secondary function to which the employee is assigned based on their Job and the Job Function of that job eg Finance Strategy Brand Marketing Sales Business Development etc This field will be inherited based on the Job Code selection and is defined by the valid SubFunction values for each Function in the Global Job Catalog, Similarity: 0.4862482551846117
#
#
#
#
# Attribute_name: PreferredName
# Field Name: PreferredName, Definition: Name the employee prefers to be identified by within the company, Similarity: 0.41151095074822563
# Field Name: MiddleName, Definition: Employees middle name, Similarity: 0.4019396409222851
# Field Name: FormalName, Definition: System generated concatenation of First Name and Last Name, Similarity: 0.37916331703701395
# Field Name: FirstName, Definition: Employees legal first given name, Similarity: 0.33747418209916313
# Field Name: TitleValue, Definition: This is the title or salutation of the Employee eg Mr Ms Mrs Dr Professor etc, Similarity: 0.33709134165188825
#
#
#
#
# Attribute_name: GoLiveDate
# Field Name: BIC_ZROLE_ID, Definition: Specifies the Role of Go to Market, Similarity: 0.3214044715875416
# Field Name: CountryName, Definition: Name of the country, Similarity: 0.25522099160641937
# Field Name: ProductLineName, Definition: A set of products that are related by the commmon physical perception or application to the marketplace Reference to Source field ZZPRDLINE, Similarity: 0.19559678223874905
# Field Name: ZZZPRDLINEDESC, Definition: A set of products that are related by the commmon physical perception or application to the marketplace Reference to Source field ZZPRDLINE, Similarity: 0.19559678223874905
# Field Name: XTNCrossPlantConfigurableMaterialValue, Definition: Alphanumeric key uniquely identifying the configurable material  Unlike the plantspecific configurable material the crossplant configurable material is valid for all plants, Similarity: 0.19277081241820923
#
#
#
#
# Attribute_name: CurrencyCode
# Field Name: CRNCY_CDV, Definition: Code used to identify the currency in which the employee is paid eg USD INR AUD etc, Similarity: 0.7182998811447316
# Field Name: CurrencyCode, Definition: Code used to identify the currency in which the employee is paid eg USD INR AUD etc, Similarity: 0.7182998811447316
# Field Name: VBAP__WAERK, Definition: The ISO4217 currency code that applies to the delivery document, Similarity: 0.6986331294396871
# Field Name: CRNCY_CDV, Definition: Code used to identify the primary currency in which the legal entity does business eg USD INR AUD etc, Similarity: 0.686324268798486
# Field Name: CurrencyCode, Definition: Code used to identify the primary currency in which the legal entity does business eg USD INR AUD etc, Similarity: 0.686324268798486
#
#
#
#
# Attribute_name: PayrollEndDate
# Field Name: WRKFRC_PAYRL_END_DT, Definition: The date upon which the person is no longer on the company payroll, Similarity: 0.7349602306923484
# Field Name: PayrollEndDate, Definition: The date upon which the person is no longer on the company payroll, Similarity: 0.7349602306923484
# Field Name: XTNDeemedPaymentDate, Definition: The field specifies the payment date, Similarity: 0.5987462950597503
# Field Name: TRMNTN_NTFCTN_DT, Definition: Date on which the Company notifies the employee as to the end of their employment contract, Similarity: 0.5831185489583243
# Field Name: TerminationNotificationDate, Definition: Date on which the Company notifies the employee as to the end of their employment contract, Similarity: 0.5831185489583243
#
#
#
#
# Attribute_name: RequisitionId
# Field Name: XTNRequisitionerName, Definition: Name of the owner of the requisition, Similarity: 0.6677368441994488
# Field Name: RequisitionId, Definition: Refers to a unique identifier assigned to a requisition , Similarity: 0.6216131448731633
# Field Name: XTNPurchaseRequisitionId, Definition: A purchase requisition number refers to a unique systemgenerated digit that helps procurement managers track the requested goods and services with a full audit trail, Similarity: 0.5690268023390676
# Field Name: XTNPurchaseRequisitionItemNumber, Definition: Specifies the unique identifier for an item within a purchase requisition, Similarity: 0.472877059013467
# Field Name: WRKFRC_ID, Definition: Identification number that is systemgenerated at the time of hire and uniquely identifies an employee through hisher tenure within PepsiCo If an employee is terminated for any reason and rejoins the organization the same GPID is assigned at time of rehire, Similarity: 0.4299002655586904
#
#
#
#
# Attribute_name: DateOfDeath
# Field Name: VBAP__run_date, Definition: The field that holds the run dates, Similarity: 0.518884669204942
# Field Name: XTNAnnexingDateTypeIndicator, Definition: The field contains the information about the date, Similarity: 0.5125292154314729
# Field Name: CALDR_YR_END_DT, Definition: The date at which the calendar year concludes, Similarity: 0.4848068529124272
# Field Name: CalendarYearEndDate, Definition: The date at which the calendar year concludes, Similarity: 0.4848068529124272
# Field Name: CreatedDateTime, Definition: The DateTime stamp when the data was created in the format YYYYMMDD HHMMSS, Similarity: 0.4755828030045591
#
#
#
#
# Attribute_name: ProbationPeriodEndDate
# Field Name: PRBTN_PRD_STRT_DT, Definition: The day month and year when the employee begins to perform their work duties Employee capacity and aptitude to perform the job are evaluated by employer during the probation period, Similarity: 0.4500316407738228
# Field Name: ProbationPeriodStartDate, Definition: The day month and year when the employee begins to perform their work duties Employee capacity and aptitude to perform the job are evaluated by employer during the probation period, Similarity: 0.4500316407738228
# Field Name: PRBTN_PRD_END_DT, Definition: Date on which the new hire's probationary period ends, Similarity: 0.43469742904131975
# Field Name: ProbationPeriodEndDate, Definition: Date on which the new hire's probationary period ends, Similarity: 0.43469742904131975
# Field Name: CNFRMTN_DT, Definition: The day month and year in the format specific to the work location country when the employee successfully completes the probation period, Similarity: 0.3801425004554006
#
#
#
#
# Attribute_name: ResignationDate
# Field Name: RESIGNATN_DT, Definition: Date on which the employee submits resignation and confirms end of service with PepsiCo, Similarity: 0.682294063897361
# Field Name: ResignationDate, Definition: Date on which the employee submits resignation and confirms end of service with PepsiCo, Similarity: 0.682294063897361
# Field Name: TRMNTN_NTFCTN_DT, Definition: Date on which the Company notifies the employee as to the end of their employment contract, Similarity: 0.6201090669056655
# Field Name: TerminationNotificationDate, Definition: Date on which the Company notifies the employee as to the end of their employment contract, Similarity: 0.6201090669056655
# Field Name: TERMINATIONDATE_DESC, Definition: Effective date of the employees termination from the Company Employees are active through their termination date The effective date of the termination action is the first day the employee is consider no longer working for PepsiCo, Similarity: 0.6008203758409372
#
#
#
#
# Attribute_name: ConfirmationDate
# Field Name: XTNCancelDate, Definition: Cancellation date, Similarity: 0.540436047985873
# Field Name: BIC_ZKOQUK, Definition: The confirmation status of the outbound delivery indicates whether picking must be explicitly confirmed for the delivery or whether picking has already been confirmed, Similarity: 0.47619374601703135
# Field Name: XTNContractReleaseDate, Definition: The date when the contract is approved or released, Similarity: 0.4751599980297216
# Field Name: XTNConfirmingOrderFlag, Definition: Indicates whether the purchase order is a confirming order or not, Similarity: 0.46970691045229407
# Field Name: VBAP___DMBE_POSTEDDATE, Definition: Posted Date is the date when the financial part of a Deal was sent or will be sent to the Exchange Market, Similarity: 0.43858926240544216
#
#
#
#
# Attribute_name: HireTypeCode
# Field Name: POSITION_CODE, Definition: The unique identifying code of the Position associated with the Employee  A position is a specific instance of a job eg P50250938, Similarity: 0.592126420574064
# Field Name: PositionCode, Definition: The unique identifying code of the Position associated with the Employee  A position is a specific instance of a job eg P50250938, Similarity: 0.592126420574064
# Field Name: LocationSubTypeCode, Definition: Unique code indicating the subtype of work location eg Z0001 for "Beverage" Z0002 for "Food" Z0004 for "Beverage  Office" Z0005 for "Food  Office" etc, Similarity: 0.5280677077720805
# Field Name: EVNT_RSN_PAYRL_EVNT_NM, Definition: Four digit alpha numeric code associated with a specific payroll eventeg TE66 LP42 CP05 etc, Similarity: 0.5235864695016603
# Field Name: EventReasonPayrollEventName, Definition: Four digit alpha numeric code associated with a specific payroll eventeg TE66 LP42 CP05 etc, Similarity: 0.5235864695016603
#
#
#
#
# Attribute_name: TerminationNotificationDate
# Field Name: BNFTS_END_DT, Definition: The end date inclusive of the employees participation in company benefit plans pursuant to his or her termination, Similarity: 0.6663716005196726
# Field Name: BenefitsEndDate, Definition: The end date inclusive of the employees participation in company benefit plans pursuant to his or her termination, Similarity: 0.6663716005196726
# Field Name: TRMNTN_NTFCTN_DT, Definition: Date on which the Company notifies the employee as to the end of their employment contract, Similarity: 0.6585545727942373
# Field Name: TerminationNotificationDate, Definition: Date on which the Company notifies the employee as to the end of their employment contract, Similarity: 0.6585545727942373
# Field Name: WRKFRC_LAST_WRKD_DT, Definition: The last day the person worked for the company prior to termination, Similarity: 0.6497539918458104
#
#
#
#
# Attribute_name: CorporateCardNumber
# Field Name: CORP_CARD_NUM, Definition: Unique number associated to a credit card issued to the employee for workrelated purchases, Similarity: 0.5563654606681642
# Field Name: CorporateCardNumber, Definition: Unique number associated to a credit card issued to the employee for workrelated purchases, Similarity: 0.5563654606681642
# Field Name: VBAP__OIH_LICIN, Definition: A number assigned to a location or organization that has a registered manufacturer , Similarity: 0.5551390048825701
# Field Name: XTNSupplierReferenceValue, Definition: The internal reference number or code specific to your company This usually identifies the person responsible for the purchasing document in your company The reference numbercode often consists of the relevant person's initials, Similarity: 0.5336222831743394
# Field Name: VBAP__FPLNR_ANA, Definition: It holds the Billing plan number or invoicing plan number, Similarity: 0.5206424068818396
#
#
#
#
# Attribute_name: ResignationTaiwanDate
# Field Name: RESIGNATN_DT, Definition: Date on which the employee submits resignation and confirms end of service with PepsiCo, Similarity: 0.6315765212917825
# Field Name: ResignationDate, Definition: Date on which the employee submits resignation and confirms end of service with PepsiCo, Similarity: 0.6315765212917825
# Field Name: TRMNTN_NTFCTN_DT, Definition: Date on which the Company notifies the employee as to the end of their employment contract, Similarity: 0.5726802137329884
# Field Name: TerminationNotificationDate, Definition: Date on which the Company notifies the employee as to the end of their employment contract, Similarity: 0.5726802137329884
# Field Name: TERMINATIONDATE_DESC, Definition: Effective date of the employees termination from the Company Employees are active through their termination date The effective date of the termination action is the first day the employee is consider no longer working for PepsiCo, Similarity: 0.5686762523833211
#
#
#
#
# Attribute_name: LocationTypeCode
# Field Name: XTNDestinationCountyCode, Definition: It shows the destination country code, Similarity: 0.5795091971208172
# Field Name: CityCode, Definition: Unique code indicating the city of the work location, Similarity: 0.5759151586658737
# Field Name: CountryCodeValue, Definition: Country code, Similarity: 0.5625036521962851
# Field Name: ProvinceCode, Definition: Unique code indicating the province of the work location, Similarity: 0.5483365912641063
# Field Name: XTNDestinationCityCode, Definition: It shows the destination city code, Similarity: 0.5438394294282448
#
#
#
#
# Attribute_name: GeoZoneCode
# Field Name: XTNRecipientLocationTimeZoneCode, Definition: The code representing the time zone of the receiving location, Similarity: 0.6199474374325503
# Field Name: CountryCodeValue, Definition: Country code, Similarity: 0.606440966900545
# Field Name: XTNDestinationCountyCode, Definition: It shows the destination country code, Similarity: 0.5779657970675336
# Field Name: CountryCode, Definition: The code uniquely identifies the country, Similarity: 0.5494002491724338
# Field Name: XTNOriginLocationCityCode, Definition: The code specifies the original city code, Similarity: 0.5157713452549274
#
#
#
#
# Attribute_name: PrimaryOwnerId
# Field Name: XTNIncotermsLocationDescription1Value, Definition: Incoterms Location 2 for Vendor master Provides additional information for the primary Incoterm, Similarity: 0.3876721320934201
# Field Name: XTNRequisitionerName, Definition: Name of the owner of the requisition, Similarity: 0.3823331073813203
# Field Name: ProductPrimarySellingUnitofMeasureName, Definition: Name of product primary selling unit of measure, Similarity: 0.3818393489436518
# Field Name: XTNPriorSupplierValue, Definition: Identifier that uniquely distinguishes the supplier from a previous instance, Similarity: 0.32801311864969795
# Field Name: XTNSupplierOfficeResponsibleSalesPersonName, Definition: Name of the Salesperson at vendor's office, Similarity: 0.32401032995277856
#
#
#
#
# Attribute_name: BusinessUnitName
# Field Name: CUST_COMPC, Definition: ERP Customer Number of a Business Partner, Similarity: 0.49426059338880535
# Field Name: CompanyName, Definition: The name associated with the code value representing the Company or Business UnitOrganizational Unit with which the Material is affiliated, Similarity: 0.4930693562299089
# Field Name: VendorDescription, Definition: This field provides the name of the vendor, Similarity: 0.46727161056452954
# Field Name: MiddleName, Definition: Employees middle name, Similarity: 0.4645191083504981
# Field Name: XTNSupplierOfficeResponsibleSalesPersonName, Definition: Name of the Salesperson at vendor's office, Similarity: 0.46330052870525507
