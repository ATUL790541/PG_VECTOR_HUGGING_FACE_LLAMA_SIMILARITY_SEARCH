# %%
import os
import psycopg2
import psycopg2.extras
from sentence_transformers import SentenceTransformer
import pandas as pd

#  connection to PostgreSQL
connection = psycopg2.connect(
    dbname="your_db_name",
    user="your_username",
    password="your_password",
    host="localhost",
    port="5432"
)


#  embedding model using Hugging Face
model_name = "sentence-transformers/all-mpnet-base-v2"  # 768-dimensional embeddings
embedding_model = SentenceTransformer(model_name)




read = pd.read_csv(r"C:\Users\atul.gupta\cleaned_new_pepsico.csv")

read

new_alis = read[['DB Field Name','Definition']].iloc[:3000]
new_alis['embedding'] = None
print(new_alis)



for index, row in new_alis.iterrows():
    field_dict = {}
    field_name = row['DB Field Name']
    definition = row['Definition']
    field_dict[field_name] = definition
    #print(field_dict)
    embeddings = embedding_model.encode([field_dict]).tolist()
    new_alis.at[index, 'embedding'] = embeddings[0]
    #print(embeddings)
new_alis


with connection.cursor() as cursor:
    for index,row in new_alis.iterrows():
        embedding_vector = row['embedding']
        #print(embedding_vector) 
        
        cursor.execute(
            """
            INSERT INTO test_3k_768(db_field_name,definition,embedding)
            VALUES(%s,%s,%s)
            """,
            (row['DB Field Name'], row['Definition'], embedding_vector)
        )  
print("Done")
connection.commit()
# Out:
# c:\Users\atul.gupta\Anaconda3\lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
#                                DB Field Name  \
# 0        HID_Form_Status__Regen_Ag__Projects
# 1     HID_Form_Status__Regen_Ag__Agriculture
# 2     HID_Form_Status__Regen_Ag__Commodities
# 3                 HID_Forms_Completion_Check
# 4                                  Thank_you
# ...                                      ...
# 2995         MaterialMarketingTargetTypeCode
# 2996                                   APLAL
# 2997                                   PLNNR
# 2998                                   STLAN
# 2999                                   STLAL
#
#                                              Definition embedding
# 0     Calculated value of overall form completion fo...      None
# 1     Calculated value of overall form completion fo...      None
# 2     Calculated value of overall form completion fo...      None
# 3     Calculated value of overall form completion fo...      None
# 4     Message is typically displayed on the last pag...      None
# ...                                                 ...       ...
# 2995  Represents what kind of marketing is being don...      None
# 2996  The group counter is used in conjunction with ...      None
# 2997  The task lists are used in production and main...      None
# 2998  Bill of Materials BOM can have different usage...      None
# 2999  In manufacturing alternative BOMs are used to ...      None
#
# [3000 rows x 3 columns]
# Done

# %%
import numpy as np
import ast

def cosine_similarity(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

def search_similar_definitions(query, top_n=5):
    query_embedding = embedding_model.encode([query]).tolist()[0]

    with connection.cursor() as cursor:
        cursor.execute("SELECT db_field_name, definition, embedding FROM test_3k_768")
        results = cursor.fetchall()
        

    similarities = []
    for row in results:
        db_field_name, definition, embedding_str = row
        
        
        embedding = ast.literal_eval(embedding_str)  
        
        similarity = cosine_similarity(query_embedding, embedding)
        similarities.append((db_field_name, definition, similarity))

    
    similarities.sort(key=lambda x: x[2], reverse=True)
    return similarities[:top_n]
#query = "Footer"
query = ["Footer","asset_status","UpdatedById","MarketUnitName","JobFunctionName","PreferredName","GoLiveDate","CurrencyCode","PayrollEndDate","RequisitionId","DateOfDeath","ProbationPeriodEndDate","ResignationDate","ConfirmationDate","HireTypeCode","TerminationNotificationDate","CorporateCardNumber","ResignationTaiwanDate","LocationTypeCode","GeoZoneCode","PrimaryOwnerId","BusinessUnitName"]
for attribute in query:
    results = search_similar_definitions(attribute, top_n=5)
    print("Attribute_name:",attribute)
    for result in results:
        print(f"Field Name: {result[0]}, Definition: {result[1]}, Similarity: {result[2]}")
    print("\n")
    print("\n")
# Out:
# Attribute_name: Footer
# Field Name: VBAP__FSH_THEME, Definition: The code defines the theme to which the fashion article belongs, Similarity: 0.28735057536382436
# Field Name: XTNDownPaymentAmount, Definition: Represents the down payment amount in the document currency, Similarity: 0.27951894080617984
# Field Name: BIC_ZSDPROMO, Definition: Indicates Promotional Sales, Similarity: 0.27491806288098053
# Field Name: VBAP__SLCST, Definition: It shows how many times the item has been reviewed, Similarity: 0.27009103866339373
# Field Name: XTNFashionThemeCode, Definition: The code specifies the fashion of the Theme, Similarity: 0.26335158096360906
#
#
#
#
# Attribute_name: asset_status
# Field Name: STS_ITM, Definition: Current status for the Item, Similarity: 0.5874586395324566
# Field Name: CH_ON, Definition: This field used for storing Last Changed date for Asset, Similarity: 0.507723892039825
# Field Name: XTNPurchasingDocumentItemStatusIndicator, Definition: Denotes Status of Purchasing Document Item, Similarity: 0.47704925707237716
# Field Name: PICK_CONF, Definition: This status indicates whether items have been picked or not, Similarity: 0.46743126743839586
# Field Name: ActiveFlag, Definition: This field indicates whether the record is active or not, Similarity: 0.4615095113935442
#
#
#
#
# Attribute_name: UpdatedById
# Field Name: XTNUpdatedById, Definition: Last User Identifier who updated the record, Similarity: 0.66459526296519
# Field Name: XTNUpdatedById, Definition: Last User Identifier who updated the data record, Similarity: 0.6355155789563759
# Field Name: UpdatedById, Definition: This field provides the identification code of person that updated, Similarity: 0.594458821003345
# Field Name: XTNUpdatedById, Definition: Last User IdJob Id Updated this Record, Similarity: 0.586240887348976
# Field Name: VBAP__XTNUpdatedById, Definition: Last User IDJob ID Updated this Record, Similarity: 0.586240887348976
#
#
#
#
# Attribute_name: MarketUnitName
# Field Name: MarketUnitName, Definition: This field provides the market unit name, Similarity: 0.7028942566334594
# Field Name: MarketUnitName, Definition: This field provides the name of the Market Unit, Similarity: 0.6860793761675174
# Field Name: VendorDescription, Definition: This field provides the name of the vendor, Similarity: 0.46751705077060884
# Field Name: VBAP__XTNDFReportingUnitName, Definition: A descriptor to unique Enterprise Data Foundation Reporting Unit Name, Similarity: 0.44699222489286494
# Field Name: ProductPrimarySellingUnitofMeasureName, Definition: Name of product primary selling unit of measure, Similarity: 0.44434206750753835
#
#
#
#
# Attribute_name: JobFunctionName
# Field Name: JOB_TITLE, Definition: Unique name for a job in the system  A job defines the general tasks and responsibilities of a role within the Company based on the Job Function and SubFunction and Grade Band Level of the role as defined by the Global Job Catalog The naming convention for the Job Title is defined within the Global Job Catalog with the exception of Frontline jobs , Similarity: 0.5877526279486601
# Field Name: JobTitleName, Definition: Unique name for a job in the system  A job defines the general tasks and responsibilities of a role within the Company based on the Job Function and SubFunction and Grade Band Level of the role as defined by the Global Job Catalog The naming convention for the Job Title is defined within the Global Job Catalog with the exception of Frontline jobs , Similarity: 0.5877526279486601
# Field Name: JOB_SUB_FUNCTION_NAME, Definition: Secondary function to which the employee is assigned based on their Job and the Job Function of that job eg Fin Strategy Brand Mktg Sales Bus Dev etc This field will be inherited based on the Job Code selection and is defined by the valid SubFunction values for each Function in the Global Job Catalog, Similarity: 0.5365092897533785
# Field Name: JobSubFunctionName, Definition: Secondary function to which the employee is assigned based on their Job and the Job Function of that job eg Fin Strategy Brand Mktg Sales Bus Dev etc This field will be inherited based on the Job Code selection and is defined by the valid SubFunction values for each Function in the Global Job Catalog, Similarity: 0.5365092897533785
# Field Name: JOB_SUB_FUNCTION, Definition: The identifying code of the secondary function to which the employee is assigned based on their Job and the Job Function of that job eg Finance Strategy Brand Marketing Sales Business Development etc This field will be inherited based on the Job Code selection and is defined by the valid SubFunction values for each Function in the Global Job Catalog, Similarity: 0.49175232625485055
#
#
#
#
# Attribute_name: PreferredName
# Field Name: PreferredName, Definition: Name the employee prefers to be identified by within the company, Similarity: 0.505091048503762
# Field Name: MiddleName, Definition: Employees middle name, Similarity: 0.4457173633300935
# Field Name: FirstName, Definition: Employees legal first given name, Similarity: 0.384295909497382
# Field Name: User, Definition: Name of the User that last saved this survey, Similarity: 0.3729400577037614
# Field Name: GeneralLedgerAccountName, Definition: This field provides the Account name, Similarity: 0.36562548958516483
#
#
#
#
# Attribute_name: GoLiveDate
# Field Name: CountryName, Definition: Name of the country, Similarity: 0.223172158867541
# Field Name: REAL_TRMNTN_RSN_NM, Definition: Currently not used by PepsiCo, Similarity: 0.2206994097397032
# Field Name: EXT_INTRVW_CMPLTD_IND, Definition: Currently not used by PepsiCo, Similarity: 0.2206994097397032
# Field Name: PRBTN_PRD_CDV, Definition: Currently not used by PepsiCo, Similarity: 0.2206994097397032
# Field Name: IMGRTN_STTS_CDV, Definition: Currently not used by PepsiCo, Similarity: 0.2206994097397032
#
#
#
#
# Attribute_name: CurrencyCode
# Field Name: XTNOpenToBuyCurrencyCode, Definition: The code which represents currency of the open to buy purchase order, Similarity: 0.6986164871991749
# Field Name: VBAP__WAERK, Definition: The ISO4217 currency code that applies to the delivery document, Similarity: 0.6238576355585691
# Field Name: CountryCodeValue, Definition: Country code, Similarity: 0.6041831035853515
# Field Name: CRNCY_CDV, Definition: Code used to identify the currency in which the employee is paid eg USD INR AUD etc, Similarity: 0.594130986766582
# Field Name: CurrencyCode, Definition: Code used to identify the currency in which the employee is paid eg USD INR AUD etc, Similarity: 0.594130986766582
#
#
#
#
# Attribute_name: PayrollEndDate
# Field Name: WRKFRC_PAYRL_END_DT, Definition: The date upon which the person is no longer on the company payroll, Similarity: 0.7257169885076057
# Field Name: PayrollEndDate, Definition: The date upon which the person is no longer on the company payroll, Similarity: 0.7257169885076057
# Field Name: MOSTRECENTHIREDATE_DESC, Definition: The date on which an employee was most recently hired or joined the organization, Similarity: 0.5754629346752865
# Field Name: MostRecentHireDate, Definition: The date on which an employee was most recently hired or joined the organization, Similarity: 0.5754629346752865
# Field Name: XTNLastPrintedDate, Definition: Date the document was last printed, Similarity: 0.571070165850564
#
#
#
#
# Attribute_name: RequisitionId
# Field Name: XTNRequisitionerName, Definition: Name of the owner of the requisition, Similarity: 0.643919652814945
# Field Name: XTNPurchaseRequisitionId, Definition: A purchase requisition number refers to a unique systemgenerated digit that helps procurement managers track the requested goods and services with a full audit trail, Similarity: 0.625938094617353
# Field Name: RequisitionId, Definition: Refers to a unique identifier assigned to a requisition , Similarity: 0.5810466819027822
# Field Name: XTNPurchaseRequisitionItemNumber, Definition: Specifies the unique identifier for an item within a purchase requisition, Similarity: 0.5472611985753904
# Field Name: XTNCentralContractId, Definition: An identifier assigned to a central contract within the Supplier Relationship Management SRM system , Similarity: 0.48421127986697043
#
#
#
#
# Attribute_name: DateOfDeath
# Field Name: XTNClosedDate, Definition: Date the line is closed, Similarity: 0.5706749648608709
# Field Name: XTNAnnexingDateTypeIndicator, Definition: The field contains the information about the date, Similarity: 0.5684989165941773
# Field Name: BIC_SGI_DATE, Definition: The date on which the delivery items were issued, Similarity: 0.5216663945753033
# Field Name: XTNLastPrintedDate, Definition: Date the document was last printed, Similarity: 0.5190934942472765
# Field Name: XTNLastTransmissionDate, Definition: Date on which the schedule for the item was last transmitted, Similarity: 0.5180228863602594
#
#
#
#
# Attribute_name: ProbationPeriodEndDate
# Field Name: CNFRMTN_DT, Definition: The day month and year in the format specific to the work location country when the employee successfully completes the probation period, Similarity: 0.40242840819293874
# Field Name: ConfirmationDate, Definition: The day month and year in the format specific to the work location country when the employee successfully completes the probation period, Similarity: 0.40242840819293874
# Field Name: PRBTN_PRD_STRT_DT, Definition: The day month and year when the employee begins to perform their work duties Employee capacity and aptitude to perform the job are evaluated by employer during the probation period, Similarity: 0.378829140191825
# Field Name: ProbationPeriodStartDate, Definition: The day month and year when the employee begins to perform their work duties Employee capacity and aptitude to perform the job are evaluated by employer during the probation period, Similarity: 0.378829140191825
# Field Name: PRBTN_PRD_END_DT, Definition: Date on which the new hire's probationary period ends, Similarity: 0.34661899185734907
#
#
#
#
# Attribute_name: ResignationDate
# Field Name: RESIGNATN_DT, Definition: Date on which the employee submits resignation and confirms end of service with PepsiCo, Similarity: 0.7007223851355794
# Field Name: ResignationDate, Definition: Date on which the employee submits resignation and confirms end of service with PepsiCo, Similarity: 0.7007223851355794
# Field Name: RESIGNATN_TWN_DT, Definition: The date on which the employee confirms the end of their service with PepsiCo This field is relevant for Taiwan only, Similarity: 0.6117801397831172
# Field Name: ResignationTaiwanDate, Definition: The date on which the employee confirms the end of their service with PepsiCo This field is relevant for Taiwan only, Similarity: 0.6117801397831172
# Field Name: WRKFRC_PAYRL_END_DT, Definition: The date upon which the person is no longer on the company payroll, Similarity: 0.6071725531760772
#
#
#
#
# Attribute_name: ConfirmationDate
# Field Name: XTNCancelDate, Definition: Cancellation date, Similarity: 0.6193484427016186
# Field Name: XTNContractReleaseDate, Definition: The date when the contract is approved or released, Similarity: 0.5601884798604256
# Field Name: XTNLastTransmissionDate, Definition: Date on which the schedule for the item was last transmitted, Similarity: 0.5252599604837251
# Field Name: BIC_SGI_DATE, Definition: The date on which the delivery items were issued, Similarity: 0.5239502809560654
# Field Name: XTNLatestPossibleGoodsRecieptDate, Definition: This is the latest acceptable date for goods receipt GRIf goods are received after this date you will receive either a warning message or an error message depending on the system setting If you receive an error message user will not be able to post the GR, Similarity: 0.5123278102248944
#
#
#
#
# Attribute_name: HireTypeCode
# Field Name: POSITION_CODE, Definition: The unique identifying code of the Position associated with the Employee  A position is a specific instance of a job eg P50250938, Similarity: 0.4798961942756231
# Field Name: PositionCode, Definition: The unique identifying code of the Position associated with the Employee  A position is a specific instance of a job eg P50250938, Similarity: 0.4798961942756231
# Field Name: FINC_CO_CDV, Definition: Code associated with the legal entity or organizational unit responsible for paying the employee , Similarity: 0.4623756457200621
# Field Name: FinanceCompanyCode, Definition: Code associated with the legal entity or organizational unit responsible for paying the employee , Similarity: 0.4623756457200621
# Field Name: BIC_ZCLSSTYP, Definition: The classification Type Code for sales level, Similarity: 0.4391284920146396
#
#
#
#
# Attribute_name: TerminationNotificationDate
# Field Name: BNFTS_END_DT, Definition: The end date inclusive of the employees participation in company benefit plans pursuant to his or her termination, Similarity: 0.6346748819752703
# Field Name: BenefitsEndDate, Definition: The end date inclusive of the employees participation in company benefit plans pursuant to his or her termination, Similarity: 0.6346748819752703
# Field Name: TRMNTN_NTFCTN_DT, Definition: Date on which the Company notifies the employee as to the end of their employment contract, Similarity: 0.6255562395171922
# Field Name: TerminationNotificationDate, Definition: Date on which the Company notifies the employee as to the end of their employment contract, Similarity: 0.6255562395171922
# Field Name: XTNCancelDate, Definition: Cancellation date, Similarity: 0.5882892506071716
#
#
#
#
# Attribute_name: CorporateCardNumber
# Field Name: CORP_CARD_NUM, Definition: Unique number associated to a credit card issued to the employee for workrelated purchases, Similarity: 0.5851482942530281
# Field Name: CorporateCardNumber, Definition: Unique number associated to a credit card issued to the employee for workrelated purchases, Similarity: 0.5851482942530281
# Field Name: CompanyCode, Definition: The company code is an organizational unit within financial accounting, Similarity: 0.5254082617058644
# Field Name: TradingPartnerCode, Definition: This field contains the company code which is and unique code for each business market, Similarity: 0.509589494585089
# Field Name: XTNCompanyCode, Definition: Company code is a legal entity overseeing all financial transaction within an organization ensuring  compliance and managing financial process, Similarity: 0.508877500004806
#
#
#
#
# Attribute_name: ResignationTaiwanDate
# Field Name: RESIGNATN_DT, Definition: Date on which the employee submits resignation and confirms end of service with PepsiCo, Similarity: 0.612398801541684
# Field Name: ResignationDate, Definition: Date on which the employee submits resignation and confirms end of service with PepsiCo, Similarity: 0.612398801541684
# Field Name: RESIGNATN_TWN_DT, Definition: The date on which the employee confirms the end of their service with PepsiCo This field is relevant for Taiwan only, Similarity: 0.5484603160359064
# Field Name: ResignationTaiwanDate, Definition: The date on which the employee confirms the end of their service with PepsiCo This field is relevant for Taiwan only, Similarity: 0.5484603160359064
# Field Name: CNFRMTN_DT, Definition: The day month and year in the format specific to the work location country when the employee successfully completes the probation period, Similarity: 0.5168919320056374
#
#
#
#
# Attribute_name: LocationTypeCode
# Field Name: XTNTransportationManagementDestinationLocationValue, Definition: The field stores the information of Location GUID 004 with Conversion Exit, Similarity: 0.5516583608080782
# Field Name: XTNTransportationManagementSourceLocationValue, Definition: The field stores the information of Location GUID 004 with Conversion Exit, Similarity: 0.5516583608080782
# Field Name: VBAP__VRKME, Definition: Code that represents the geographical sales district or region of the customer, Similarity: 0.5468206097896616
# Field Name: CountryCodeValue, Definition: Country code, Similarity: 0.5204811933435718
# Field Name: BIC_ZILN_VEN, Definition: International Location Number Vendor Identifier, Similarity: 0.5017786591106214
#
#
#
#
# Attribute_name: GeoZoneCode
# Field Name: CountryCodeValue, Definition: Country code, Similarity: 0.7663937816315899
# Field Name: XTNRecipientLocationTimeZoneCode, Definition: The code representing the time zone of the receiving location, Similarity: 0.6243284541455115
# Field Name: CountryIsoCode, Definition: ISO Code of the country, Similarity: 0.6125974062421058
# Field Name: CountryCode, Definition: The code uniquely identifies the country, Similarity: 0.5867575095995307
# Field Name: VBAP__FERC_IND, Definition: Code for countryspecific regions where the customer is geographically located A State or Region sometimes called a Province or Territory within a customer address varies by country and designates an area or a division within the country, Similarity: 0.580292863115177
#
#
#
#
# Attribute_name: PrimaryOwnerId
# Field Name: XTNRequisitionerName, Definition: Name of the owner of the requisition, Similarity: 0.5350910436575097
# Field Name: FirstName, Definition: Employees legal first given name, Similarity: 0.3870897703740407
# Field Name: PoCreatedByName, Definition: Name of the user who created the vendor master record in the data source system, Similarity: 0.3845274475043566
# Field Name: XTNCreatedById, Definition: User IdentifierJob Identifier created this Record, Similarity: 0.3790660487365744
# Field Name: XTNBaseLocationId, Definition: The ID specifies the base location of the firm, Similarity: 0.37573475475601065
#
#
#
#
# Attribute_name: BusinessUnitName
# Field Name: XTNOrganizationId, Definition: Organization identifier, Similarity: 0.5221832941169081
# Field Name: CompanyName, Definition: The name associated with the code value representing the Company or Business UnitOrganizational Unit with which the Material is affiliated, Similarity: 0.496861034244412
# Field Name: BusinessGroupCode, Definition: Code identifying the Business Group Code ie SUS, Similarity: 0.4866128369227331
# Field Name: MarketUnitName, Definition: This field provides the market unit name, Similarity: 0.48585031072738916
# Field Name: EMPLYR_IDNTN_NUM, Definition: Unique identification number assigned to a business entity by the governing authority in its country of registration, Similarity: 0.46716628596582577
